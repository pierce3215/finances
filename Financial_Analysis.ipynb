# %% [markdown]
# <a href="https://colab.research.google.com/github/pierce3215/finances/blob/main/Financial_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt
import datetime as datetime
from prophet import Prophet
import plotly.express as px
from pandas import read_csv

# %%
ticker = yf.Ticker(input("ENTER THE STOCK WHOSE PREDICTION YOU WANT : "))
# Out:
# ENTER THE STOCK WHOSE PREDICTION YOU WANT : NEE

# %%
hist = ticker.history(period="3y")

# %%
print(hist)
# Out:
#                                 Open       High        Low      Close  \
# Date
# 2020-10-26 00:00:00-04:00  70.578848  70.970071  69.712071  70.899788
# 2020-10-27 00:00:00-04:00  71.347220  71.618966  70.297718  71.009880
# 2020-10-28 00:00:00-04:00  70.035361  71.262906  69.613690  69.772987
# 2020-10-29 00:00:00-04:00  69.698008  70.307094  68.348657  69.351303
# 2020-10-30 00:00:00-04:00  69.088949  69.669917  67.936370  68.601677
# ...                              ...        ...        ...        ...
# 2023-10-19 00:00:00-04:00  53.279999  53.990002  52.380001  52.389999
# 2023-10-20 00:00:00-04:00  51.950001  52.689999  51.689999  51.959999
# 2023-10-23 00:00:00-04:00  51.270000  52.560001  50.950001  51.520000
# 2023-10-24 00:00:00-04:00  54.439999  55.430000  53.110001  55.119999
# 2023-10-25 00:00:00-04:00  55.610001  56.790001  54.919998  56.369999
#
#                              Volume  Dividends  Stock Splits
# Date
# ...

# %%
ticker.history_metadata
# Out:
# {'currency': 'USD',
#  'symbol': 'NEE',
#  'exchangeName': 'NYQ',
#  'instrumentType': 'EQUITY',
#  'firstTradeDate': 99153000,
#  'regularMarketTime': 1698248421,
#  'gmtoffset': -14400,
#  'timezone': 'EDT',
#  'exchangeTimezoneName': 'America/New_York',
#  'regularMarketPrice': 56.37,
#  'chartPreviousClose': 75.768,
#  'priceHint': 2,
#  'currentTradingPeriod': {'pre': {'timezone': 'EDT',
#    'start': 1698220800,
#    'end': 1698240600,
#    'gmtoffset': -14400},
#   'regular': {'timezone': 'EDT',
#    'start': 1698240600,
#    'end': 1698264000,
#    'gmtoffset': -14400},
#   'post': {'timezone': 'EDT',
#    'start': 1698264000,
#    'end': 1698278400,
#    'gmtoffset': -14400}},
#  'dataGranularity': '1d',
#  'range': '3y',
#  'validRanges': ['1d',
#   '5d',
#   '1mo',
#   '3mo',
#   '6mo',
#   '1y',
#   '2y',
#   '5y',
#   '10y',
#   'ytd',
#   'max']}

# %%
ticker.actions
# Out:
#                            Dividends  Stock Splits
# Date
# 2020-10-27 00:00:00-04:00      0.000           4.0
# 2020-11-25 00:00:00-05:00      0.350           0.0
# 2021-02-25 00:00:00-05:00      0.385           0.0
# 2021-06-01 00:00:00-04:00      0.385           0.0
# 2021-08-26 00:00:00-04:00      0.385           0.0
# 2021-11-24 00:00:00-05:00      0.385           0.0
# 2022-02-28 00:00:00-05:00      0.425           0.0
# 2022-05-27 00:00:00-04:00      0.425           0.0
# 2022-08-29 00:00:00-04:00      0.425           0.0
# 2022-11-23 00:00:00-05:00      0.425           0.0
# 2023-02-27 00:00:00-05:00      0.468           0.0
# 2023-05-26 00:00:00-04:00      0.468           0.0
# 2023-08-29 00:00:00-04:00      0.468           0.0

# %%
ticker.dividends
# Out:
# Date
# 2022-12-16 00:00:00-05:00    1.781
# 2023-03-17 00:00:00-04:00    1.506
# 2023-06-16 00:00:00-04:00    1.638
# 2023-09-15 00:00:00-04:00    1.583
# Name: Dividends, dtype: float64

# %%
ticker.splits
# Out:
# Date
# 2020-10-27 00:00:00-04:00    4.0
# Name: Stock Splits, dtype: float64

# %%
ticker.capital_gains
# Out:
# []

# %%
ticker.get_shares_full(start="2022-01-01", end=None)
# Out:
# 2022-02-11 00:00:00-05:00    1962140032
# 2022-02-19 00:00:00-05:00    1962739968
# 2022-02-22 00:00:00-05:00    1962739968
# 2022-03-15 00:00:00-04:00    1963239936
# 2022-03-16 00:00:00-04:00    1962739968
#                                 ...
# 2023-08-21 00:00:00-04:00    2023709952
# 2023-10-17 00:00:00-04:00    2023709952
# 2023-10-17 00:00:00-04:00    2027810048
# 2023-10-24 00:00:00-04:00    2023709952
# 2023-10-25 00:00:00-04:00    2023709952
# Length: 64, dtype: int64

# %%
income_stmt = ticker.income_stmt
print(income_stmt)
# Out:
#                                                            2022-12-31  \
# Tax Effect Of Unusual Items                           38689457.202505
# Tax Rate For Calcs                                           0.152923
# Normalized EBITDA                                        8954000000.0
# Total Unusual Items                                       253000000.0
# Total Unusual Items Excluding Goodwill                    253000000.0
# Net Income From Continuing Operation Net Minori...       4147000000.0
# Reconciled Depreciation                                  4790000000.0
# Reconciled Cost Of Revenue                              10530000000.0
# EBITDA                                                   9207000000.0
# EBIT                                                     4417000000.0
# Net Interest Income                                      -585000000.0
# Interest Expense                                          585000000.0
# ...

# %%
ticker.quarterly_income_stmt
# Out:
#                                                            2023-06-30  \
# Tax Effect Of Unusual Items                           21269846.455407
# Tax Rate For Calcs                                           0.162365
# Normalized EBITDA                                        4616000000.0
# Total Unusual Items                                       131000000.0
# Total Unusual Items Excluding Goodwill                    131000000.0
# Net Income From Continuing Operation Net Minori...       2795000000.0
# Reconciled Depreciation                                  1551000000.0
# Reconciled Cost Of Revenue                               2429000000.0
# EBITDA                                                   4747000000.0
# EBIT                                                     3196000000.0
# Net Interest Income                                      -135000000.0
# Interest Expense                                          135000000.0
# ...

# %%
ticker.balance_sheet
# Out:
#                                                      2022-12-31  \
# Ordinary Shares Number                             1987000000.0
# Share Issued                                       1987000000.0
# Net Debt                                          63365000000.0
# Total Debt                                        64966000000.0
# Tangible Book Value                               34375000000.0
# ...                                                         ...
# Accounts Receivable                                4349000000.0
# Allowance For Doubtful Accounts Receivable          -54000000.0
# Gross Accounts Receivable                          4403000000.0
# Cash Cash Equivalents And Short Term Investments   1601000000.0
# Cash And Cash Equivalents                          1601000000.0
#
#                                                      2021-12-31  \
# Ordinary Shares Number                             1963000000.0
# Share Issued                                       1963000000.0
# ...

# %%
ticker.cashflow
# Out:
#                                             2022-12-31     2021-12-31  \
# Free Cash Flow                           -1480000000.0   -277000000.0
# Repurchase Of Capital Stock                        NaN            NaN
# Repayment Of Debt                        -5650000000.0 -10020000000.0
# Issuance Of Debt                         15938000000.0  16683000000.0
# Issuance Of Capital Stock                 1460000000.0     14000000.0
# ...                                                ...            ...
# Earnings Losses From Equity Investments   -203000000.0   -666000000.0
# Gain Loss On Investment Securities        1378000000.0   2005000000.0
# Net Foreign Currency Exchange Gain Loss   -104000000.0    -94000000.0
# Gain Loss On Sale Of Business             -602000000.0   -146000000.0
# Net Income From Continuing Operations     3246000000.0   2827000000.0
#
#                                             2020-12-31     2019-12-31
# ...

# %%
ticker.quarterly_cashflow
# Out:
#                                                   2023-06-30    2023-03-31  \
# Free Cash Flow                                   582000000.0  -621000000.0
# Repayment Of Debt                              -2396000000.0 -2801000000.0
# Issuance Of Debt                                3990000000.0  8490000000.0
# Issuance Of Capital Stock                          1000000.0  2502000000.0
# Capital Expenditure                            -2504000000.0 -2294000000.0
# Interest Paid Supplemental Data                  602000000.0   549000000.0
# Income Tax Paid Supplemental Data                136000000.0     2000000.0
# End Cash Position                               2754000000.0  4189000000.0
# Beginning Cash Position                         4189000000.0  3441000000.0
# Effect Of Exchange Rate Changes                   -2000000.0     2000000.0
# Changes In Cash                                -1433000000.0   746000000.0
# ...

# %%
ticker.options
# Out:
# ('2023-10-27',
#  '2023-11-03',
#  '2023-11-10',
#  '2023-11-17',
#  '2023-11-24',
#  '2023-12-01',
#  '2023-12-15',
#  '2024-01-19',
#  '2024-03-15',
#  '2024-06-21',
#  '2025-01-17',
#  '2025-09-19',
#  '2026-01-16')

# %%
ticker.news
# Out:
# [{'uuid': '3bc6cb53-1a12-3f2b-97f0-d0a158f85188',
#   'title': 'This Ultra-High-Yield Stock Sheds More Light on Its Revised Dividend Growth Plan',
#   'publisher': 'Motley Fool',
#   'link': 'https://finance.yahoo.com/m/3bc6cb53-1a12-3f2b-97f0-d0a158f85188/this-ultra-high-yield-stock.html',
#   'providerPublishTime': 1698247200,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/NPtPsK0XWwNLrnIbLVLg7A--~B/aD0xNDU4O3c9MjA1NzthcHBpZD15dGFjaHlvbg--/https://media.zenfs.com/en/motleyfool.com/264c15c12881d6c0e87e5f0665d4d400',
#      'width': 2057,
#      'height': 1458,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/ZSoSHqu_xKhagWt3tGmHIw--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/motleyfool.com/264c15c12881d6c0e87e5f0665d4d400',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]},
#   'relatedTickers': ['NEE', 'BEP']},
# ...

# %%
opt = ticker.option_chain('2023-11-17')
print(opt)
# Out:
# Options(calls=        contractSymbol             lastTradeDate  strike  lastPrice    bid  \
# 0   NEE231117C00030000 2023-10-05 14:03:23+00:00    30.0      19.50  26.60
# 1   NEE231117C00035000 2023-09-05 13:53:09+00:00    35.0      31.92  14.00
# 2   NEE231117C00037500 2023-10-19 14:10:41+00:00    37.5      15.90  19.20
# 3   NEE231117C00040000 2023-10-20 16:32:28+00:00    40.0      12.38  16.70
# 4   NEE231117C00042500 2023-10-10 18:48:55+00:00    42.5       9.30  14.20
# 5   NEE231117C00045000 2023-10-23 18:02:21+00:00    45.0       7.42  11.70
# 6   NEE231117C00047500 2023-10-24 14:05:06+00:00    47.5       6.60   9.30
# 7   NEE231117C00050000 2023-10-25 15:16:23+00:00    50.0       7.00   7.00
# 8   NEE231117C00052500 2023-10-25 15:19:46+00:00    52.5       4.82   4.60
# 9   NEE231117C00055000 2023-10-25 15:16:22+00:00    55.0       2.87   2.75
# 10  NEE231117C00057500 2023-10-25 14:53:12+00:00    57.5       1.30   1.35
# ...
